# %%
import datetime
import pandas as pd
import os
import arcpy
import numpy as np
import matplotlib.pyplot as plt
import calendar
import time

pd.reset_option('display.float_format')

# %%
# this was going to be used for a date function but we decided not to use it
# def getDateRangeFromWeek(p_year,p_week):
#     firstdayofweek = datetime.datetime.strptime(f'{p_year}-W{int(p_week )- 1}-1', "%Y-W%W-%w").date()
#     lastdayofweek = firstdayofweek + datetime.timedelta(days=6.9)
#     return firstdayofweek

# %%
#import table using relative path and create dataframe
btsutah = ".\\utah_allcounties.csv"
df = pd.read_csv(btsutah)
df.head()
# Out:
#    Unnamed: 0   level        date  state_fips state_code  county_fips  \
# 0        2778  County  2020-07-06          49         UT      49001.0
# 1        2779  County  2020-07-06          49         UT      49003.0
# 2        2780  County  2020-07-06          49         UT      49005.0
# 3        2781  County  2020-07-06          49         UT      49007.0
# 4        2782  County  2020-07-06          49         UT      49009.0
#
#              county  pop_stay_at_home  pop_not_stay_at_home     trips  \
# 0     Beaver County            1667.0                4913.0   20121.0
# 1  Box Elder County           12944.0               42006.0  153413.0
# 2      Cache County           31376.0               95692.0  353378.0
# 3     Carbon County            4990.0               15279.0   68015.0
# 4    Daggett County             335.0                 645.0    2084.0
#
#    trips_1  trips_1_3  trips_3_5  trips_5_10  trips_10_25  trips_25_50  \
# 0   7196.0     4952.0     1045.0      1173.0       1656.0       2174.0
# 1  38087.0    31969.0    13760.0     12954.0      28662.0      13907.0
# 2  88692.0    93047.0    39008.0     48054.0      46512.0      16936.0
# 3  15912.0    22899.0     3576.0      8174.0       7414.0       5583.0
# 4    392.0      429.0      137.0       475.0        417.0        106.0
#
#    trips_50_100  trips_100_250  trips_250_500  trips_500
# 0        1241.0          578.0           85.0       21.0
# 1        8923.0         3815.0          959.0      377.0
# 2       13197.0         5296.0         2073.0      563.0
# 3        3094.0         1130.0          208.0       25.0
# 4         113.0           15.0            0.0        0.0

# %%
# add columns and convert date to different date formats - week number, month, etc
df["date"] = df["date"].astype('datetime64[ns]')
df["weeknumber"] = df["date"].apply(lambda x: x.isocalendar()[1])
df["month"] = df["date"].apply(lambda x: x.month)
df["monthname"] = df["date"].apply(lambda x: calendar.month_name[x.month])
df["year"] = df["date"].apply(lambda x: x.year)
# add column for total population - to be used for later percentage calc
df["poptotal"] = df["pop_stay_at_home"] + df["pop_not_stay_at_home"]

# for date function that we did not use
#df['firstday'] = pd.to_datetime(np.vectorize(getDateRangeFromWeek)(2020, df['weeknumber']))

# check new columns
df[["date", "weeknumber", "year", "month", "monthname", "poptotal"]]
# Out:
#             date  weeknumber  year  month  monthname   poptotal
# 0     2020-07-06          28  2020      7       July     6580.0
# 1     2020-07-06          28  2020      7       July    54950.0
# 2     2020-07-06          28  2020      7       July   127068.0
# 3     2020-07-06          28  2020      7       July    20269.0
# 4     2020-07-06          28  2020      7       July      980.0
# ...          ...         ...   ...    ...        ...        ...
# 19045 2020-09-22          39  2020      9  September  3161105.0
# 19046 2020-09-23          39  2020      9  September  3161105.0
# 19047 2020-09-24          39  2020      9  September  3161105.0
# 19048 2020-09-25          39  2020      9  September  3161105.0
# 19049 2020-09-26          39  2020      9  September  3161105.0
#
# [19050 rows x 6 columns]

# %%
# check all column names
df.columns
# Out:
# Index(['Unnamed: 0', 'level', 'date', 'state_fips', 'state_code',
#        'county_fips', 'county', 'pop_stay_at_home', 'pop_not_stay_at_home',
#        'trips', 'trips_1', 'trips_1_3', 'trips_3_5', 'trips_5_10',
#        'trips_10_25', 'trips_25_50', 'trips_50_100', 'trips_100_250',
#        'trips_250_500', 'trips_500', 'weeknumber', 'month', 'monthname',
#        'year', 'poptotal'],
#       dtype='object')

# %%
# check that all columns have the correct number of values
df["county"].value_counts()
# Out:
# Duchesne County      635
# Sanpete County       635
# San Juan County      635
# Juab County          635
# Millard County       635
# Wayne County         635
# Wasatch County       635
# Carbon County        635
# Davis County         635
# Iron County          635
# Rich County          635
# Salt Lake County     635
# Tooele County        635
# Garfield County      635
# Sevier County        635
# Grand County         635
# Kane County          635
# Washington County    635
# Box Elder County     635
# Emery County         635
# Daggett County       635
# Morgan County        635
# Summit County        635
# Cache County         635
# Piute County         635
# Beaver County        635
# Uintah County        635
# Weber County         635
# Utah County          635
# Name: county, dtype: int64

# %%
# filter data to county of interest
dfslc = df[df["county"]=="Box Elder County"]
dfslc
# Out:
#        Unnamed: 0   level       date  state_fips state_code  county_fips  \
# 1            2779  County 2020-07-06          49         UT      49003.0
# 30           5921  County 2020-07-07          49         UT      49003.0
# 59           9063  County 2020-07-08          49         UT      49003.0
# 88          12205  County 2020-07-09          49         UT      49003.0
# 117         15347  County 2020-07-10          49         UT      49003.0
# ...           ...     ...        ...         ...        ...          ...
# 18899     2014885  County 2020-09-22          49         UT      49003.0
# 18928     2018011  County 2020-09-23          49         UT      49003.0
# 18957     2021130  County 2020-09-24          49         UT      49003.0
# 18987     2024275  County 2020-09-25          49         UT      49003.0
# 19015     2027440  County 2020-09-26          49         UT      49003.0
#
#                  county  pop_stay_at_home  pop_not_stay_at_home     trips  \
# 1      Box Elder County           12944.0               42006.0  153413.0
# 30     Box Elder County           12999.0               41951.0  155696.0
# 59     Box Elder County           13171.0               41779.0  155902.0
# 88     Box Elder County           13012.0               41938.0  165104.0
# 117    Box Elder County           12289.0               42661.0  167074.0
# ...                 ...               ...                   ...       ...
# 18899  Box Elder County           14296.0               40654.0  165506.0
# 18928  Box Elder County           12949.0               42001.0  176418.0
# 18957  Box Elder County           12339.0               42611.0  160988.0
# 18987  Box Elder County           12332.0               42618.0  179252.0
# 19015  Box Elder County           13806.0               41144.0  169737.0
#
#        ...  trips_25_50  trips_50_100  trips_100_250  trips_250_500  \
# 1      ...      13907.0        8923.0         3815.0          959.0
# 30     ...      13244.0        8651.0         5058.0         1411.0
# 59     ...      14032.0        8301.0         4561.0         1119.0
# 88     ...      12030.0        8743.0         4199.0         1396.0
# 117    ...      13074.0        8039.0         4299.0         1166.0
# ...    ...          ...           ...            ...            ...
# 18899  ...      14259.0        7973.0         4358.0         1095.0
# 18928  ...      14276.0        6962.0         4756.0         1543.0
# 18957  ...      14516.0        6980.0         4540.0         1761.0
# 18987  ...      14816.0        7579.0         5181.0         1457.0
# 19015  ...      14718.0        6951.0         5373.0         1532.0
#
#        trips_500  weeknumber  month  monthname  year  poptotal
# 1          377.0          28      7       July  2020   54950.0
# 30         548.0          28      7       July  2020   54950.0
# 59         496.0          28      7       July  2020   54950.0
# 88         594.0          28      7       July  2020   54950.0
# 117        432.0          28      7       July  2020   54950.0
# ...          ...         ...    ...        ...   ...       ...
# 18899      246.0          39      9  September  2020   54950.0
# 18928      335.0          39      9  September  2020   54950.0
# 18957      285.0          39      9  September  2020   54950.0
# 18987      250.0          39      9  September  2020   54950.0
# 19015      362.0          39      9  September  2020   54950.0
#
# [635 rows x 25 columns]

# %%
# check number of values
dfslc["year"].value_counts()
dfslc["month"].value_counts()
# Out:
# 8     62
# 7     62
# 5     62
# 3     62
# 1     62
# 6     60
# 4     60
# 2     57
# 9     56
# 12    31
# 10    31
# 11    30
# Name: month, dtype: int64

# %%
# aggregate data - sum trips by week
slctripsbyweek_sum = dfslc.groupby(['weeknumber', 'year'], as_index=False)[['trips', 'trips_1', 'trips_1_3', 'trips_3_5', 'trips_5_10',
       'trips_10_25', 'trips_25_50', 'trips_50_100', 'trips_100_250', 'trips_250_500', 'trips_500']].sum()
slctripsbyweek_sum = slctripsbyweek_sum[(slctripsbyweek_sum['weeknumber']<40) & (slctripsbyweek_sum['weeknumber']>1)]
slctripsbyweek_sum
# Out:
#     weeknumber  year      trips   trips_1  trips_1_3  trips_3_5  trips_5_10  \
# 2            2  2019  1468512.0  363321.0   371594.0   124338.0    124312.0
# 3            2  2020  1408600.0  370965.0   349691.0   143008.0    116260.0
# 4            3  2019  1505719.0  409473.0   380752.0   122095.0    125789.0
# 5            3  2020  1424965.0  383475.0   346377.0   135476.0    126246.0
# 6            4  2019  1536271.0  382548.0   401932.0   139351.0    131369.0
# ..         ...   ...        ...       ...        ...        ...         ...
# 73          37  2020  1109346.0  256486.0   250720.0    92232.0     90181.0
# 74          38  2019  1988097.0  411492.0   513135.0   182962.0    221972.0
# 75          38  2020  1148366.0  280166.0   262362.0    92491.0     94528.0
# 76          39  2019  1988987.0  430379.0   516548.0   206291.0    219959.0
# 77          39  2020   995381.0  249951.0   220835.0    86878.0     85130.0
#
#     trips_10_25  trips_25_50  trips_50_100  trips_100_250  trips_250_500  \
# 2      265524.0     121723.0       62772.0        24693.0         7545.0
# 3      239243.0     106160.0       51535.0        24017.0         6539.0
# 4      248891.0     123358.0       60142.0        25045.0         7424.0
# 5      244077.0     104537.0       51341.0        26195.0         5899.0
# 6      252338.0     134449.0       57299.0        26800.0         7165.0
# ..          ...          ...           ...            ...            ...
# 73     206661.0      99943.0       62524.0        37418.0         9374.0
# 74     392492.0     186738.0       54320.0        19316.0         3223.0
# 75     209713.0     100013.0       59568.0        35265.0        10319.0
# 76     385535.0     156887.0       48495.0        19315.0         3858.0
# 77     183298.0      86217.0       43326.0        29366.0         8556.0
#
#     trips_500
# 2      2690.0
# 3      1182.0
# 4      2750.0
# 5      1342.0
# 6      3020.0
# ..        ...
# 73     3807.0
# 74     2447.0
# 75     3941.0
# 76     1720.0
# 77     1824.0
#
# [76 rows x 13 columns]

# %%
# filter 2019 and 2020 observations and save to variables - then merge into a table with weeknumber
# we did this so we could graph multiple x values - compare 2019 and 2020 trips
weeknumbers = slctripsbyweek_sum[['weeknumber']].drop_duplicates()
df2019 = slctripsbyweek_sum[slctripsbyweek_sum['year'] == 2019]
df2019.columns = ['weeknumber', 'year', 'trips_2019', 'trips_1_2019','trips_1_3_2019', 'trips_3_5_2019', 'trips_5_10_2019',
       'trips_10_25_2019', 'trips_25_50_2019', 'trips_50_100_2019', 'trips_100_250_2019', 'trips_250_500_2019', 'trips_500_2019']
df2020 = slctripsbyweek_sum[slctripsbyweek_sum['year'] == 2020]
df2020.columns = ['weeknumber', 'year', 'trips_2020', 'trips_1_2020','trips_1_3_2020', 'trips_3_5_2020', 'trips_5_10_2020',
       'trips_10_25_2020', 'trips_25_50_2020', 'trips_50_100_2020', 'trips_100_250_2020', 'trips_250_500_2020', 'trips_500_2020']
dfslcpivot = weeknumbers.merge(df2019.drop(['year'], axis = 1), left_on = 'weeknumber', right_on = 'weeknumber', how = 'inner')
dfslcpivot = dfslcpivot.merge(df2020.drop(['year'], axis = 1), left_on = 'weeknumber', right_on = 'weeknumber', how = 'inner')
dfslcpivot
# Out:
#     weeknumber  trips_2019  trips_1_2019  trips_1_3_2019  trips_3_5_2019  \
# 0            2   1468512.0      363321.0        371594.0        124338.0
# 1            3   1505719.0      409473.0        380752.0        122095.0
# 2            4   1536271.0      382548.0        401932.0        139351.0
# 3            5   1534132.0      399745.0        384697.0        144952.0
# 4            6   1466387.0      377005.0        370358.0        128436.0
# 5            7   1439021.0      368156.0        353657.0        135725.0
# 6            8   1491891.0      386739.0        402943.0        129670.0
# 7            9   1482317.0      369611.0        400192.0        140891.0
# 8           10   1509271.0      376951.0        401632.0        136156.0
# 9           11   1630075.0      416914.0        453681.0        146301.0
# 10          12   1731410.0      400609.0        466267.0        164364.0
# 11          13   1903004.0      453716.0        517052.0        171155.0
# 12          14   1793165.0      424194.0        478230.0        174808.0
# 13          15   1763895.0      378065.0        482663.0        184186.0
# 14          16   1899724.0      435545.0        499534.0        189383.0
# 15          17   1806551.0      413122.0        482719.0        181212.0
# 16          18   1921617.0      432150.0        534932.0        201743.0
# 17          19   1859798.0      411254.0        526812.0        192286.0
# 18          20   1804966.0      409955.0        505627.0        178762.0
# 19          21   1861010.0      414089.0        536851.0        188806.0
# 20          22   1889250.0      422992.0        541433.0        199226.0
# 21          23   1991061.0      462954.0        569370.0        200611.0
# 22          24   1930491.0      437883.0        550285.0        213839.0
# 23          25   1908166.0      430245.0        544586.0        193136.0
# 24          26   2075196.0      498842.0        586544.0        197691.0
# 25          27   2119227.0      466342.0        622003.0        224505.0
# 26          28   2070947.0      452984.0        573847.0        230530.0
# 27          29   2177592.0      514275.0        602999.0        237525.0
# 28          30   2128415.0      462036.0        619144.0        235002.0
# 29          31   2235654.0      471788.0        633130.0        256600.0
# 30          32   2118638.0      453383.0        596089.0        240813.0
# 31          33   2169757.0      518342.0        616327.0        196644.0
# 32          34   2156135.0      481843.0        581398.0        195462.0
# 33          35   2152229.0      486361.0        599147.0        185730.0
# 34          36   2104409.0      450070.0        567742.0        210112.0
# 35          37   2022088.0      414215.0        531155.0        191920.0
# 36          38   1988097.0      411492.0        513135.0        182962.0
# 37          39   1988987.0      430379.0        516548.0        206291.0
#
#     trips_5_10_2019  trips_10_25_2019  trips_25_50_2019  trips_50_100_2019  \
# 0          124312.0          265524.0          121723.0            62772.0
# 1          125789.0          248891.0          123358.0            60142.0
# 2          131369.0          252338.0          134449.0            57299.0
# 3          130030.0          256877.0          126245.0            57550.0
# 4          127331.0          244508.0          124179.0            58103.0
# 5          129491.0          236262.0          123041.0            58055.0
# 6          122430.0          237871.0          120238.0            53744.0
# 7          128372.0          234501.0          117972.0            51839.0
# 8          131202.0          249619.0          118999.0            53541.0
# 9          140211.0          260094.0          121043.0            53353.0
# 10         147157.0          316644.0          130215.0            57069.0
# 11         154129.0          346538.0          141374.0            59780.0
# 12         154563.0          310138.0          127518.0            60167.0
# 13         160436.0          322619.0          117434.0            52507.0
# 14         168026.0          366371.0          125388.0            51217.0
# 15         163529.0          318318.0          149469.0            59474.0
# 16         173278.0          336541.0          141755.0            60630.0
# 17         177795.0          334449.0          132479.0            52540.0
# 18         156826.0          339498.0          126400.0            49242.0
# 19         178690.0          335536.0          121589.0            48979.0
# 20         174644.0          332023.0          132145.0            47999.0
# 21         177341.0          352853.0          136647.0            52693.0
# 22         163762.0          332274.0          143125.0            51624.0
# 23         153964.0          363313.0          132328.0            50712.0
# 24         164807.0          389664.0          151830.0            52375.0
# 25         187048.0          390806.0          147506.0            50479.0
# 26         184073.0          404192.0          150948.0            49960.0
# 27         197260.0          397074.0          152848.0            48038.0
# 28         194564.0          396638.0          145359.0            47885.0
# 29         197180.0          445341.0          148979.0            55179.0
# 30         170476.0          418770.0          155174.0            56313.0
# 31         185392.0          370008.0          192542.0            63797.0
# 32         242205.0          382557.0          180190.0            64558.0
# 33         202115.0          402037.0          187869.0            58086.0
# 34         204406.0          424362.0          156357.0            51517.0
# 35         230977.0          397480.0          173936.0            52079.0
# 36         221972.0          392492.0          186738.0            54320.0
# 37         219959.0          385535.0          156887.0            48495.0
#
#     trips_100_250_2019  ...  trips_1_2020  trips_1_3_2020  trips_3_5_2020  \
# 0              24693.0  ...      370965.0        349691.0        143008.0
# 1              25045.0  ...      383475.0        346377.0        135476.0
# 2              26800.0  ...      355972.0        350117.0        127194.0
# 3              23777.0  ...      370916.0        347407.0        140375.0
# 4              26983.0  ...      360098.0        350034.0        130901.0
# 5              24128.0  ...      400301.0        370346.0        138214.0
# 6              27793.0  ...      405081.0        381500.0        134182.0
# 7              27089.0  ...      407374.0        391755.0        143226.0
# 8              28907.0  ...      366042.0        341438.0        130833.0
# 9              27281.0  ...      396707.0        323505.0        129328.0
# 10             36298.0  ...      383072.0        292061.0        114574.0
# 11             43078.0  ...      344647.0        246861.0         98199.0
# 12             48249.0  ...      368928.0        244074.0         90517.0
# 13             49447.0  ...      378122.0        264786.0        103802.0
# 14             45845.0  ...      286127.0        272021.0        116982.0
# 15             30624.0  ...      367635.0        291400.0        107477.0
# 16             32559.0  ...      349475.0        306456.0        119872.0
# 17             23369.0  ...      335876.0        296043.0        113390.0
# 18             28723.0  ...      382038.0        293177.0        121648.0
# 19             26524.0  ...      375668.0        320095.0        133908.0
# 20             29888.0  ...      341360.0        291842.0        111843.0
# 21             29143.0  ...      363387.0        271938.0        115020.0
# 22             28079.0  ...      388103.0        298947.0        113795.0
# 23             29774.0  ...      328710.0        249272.0        105156.0
# 24             24336.0  ...      333295.0        252060.0        104668.0
# 25             23127.0  ...      298439.0        233385.0         99542.0
# 26             17822.0  ...      287080.0        225870.0         91070.0
# 27             20237.0  ...      272969.0        224781.0        105319.0
# 28             21176.0  ...      254220.0        217192.0        103126.0
# 29             20543.0  ...      239507.0        215526.0         92832.0
# 30             21473.0  ...      273661.0        233619.0         97205.0
# 31             21336.0  ...      272216.0        245483.0         92671.0
# 32             21819.0  ...      253201.0        224411.0         90040.0
# 33             23769.0  ...      235859.0        231177.0         87300.0
# 34             29033.0  ...      254528.0        265517.0         97662.0
# 35             23697.0  ...      256486.0        250720.0         92232.0
# 36             19316.0  ...      280166.0        262362.0         92491.0
# 37             19315.0  ...      249951.0        220835.0         86878.0
#
#     trips_5_10_2020  trips_10_25_2020  trips_25_50_2020  trips_50_100_2020  \
# 0          116260.0          239243.0          106160.0            51535.0
# 1          126246.0          244077.0          104537.0            51341.0
# 2          126329.0          250224.0          117131.0            52442.0
# 3          123007.0          248731.0          117612.0            55390.0
# 4          127545.0          236065.0          112856.0            58335.0
# 5          132948.0          263006.0          142646.0            64740.0
# 6          131134.0          249928.0          127303.0            62923.0
# 7          124669.0          266510.0          120364.0            53440.0
# 8          114264.0          236182.0          114745.0            57430.0
# 9          114876.0          222284.0          105694.0            60707.0
# 10         102900.0          196544.0           85737.0            55614.0
# 11          81459.0          171734.0           73266.0            47087.0
# 12          82133.0          171400.0           69164.0            45553.0
# 13          84154.0          176017.0           70061.0            37401.0
# 14          83725.0          198674.0           84725.0            39706.0
# 15         108984.0          189402.0           82008.0            39362.0
# 16         108990.0          195996.0           80130.0            42754.0
# 17         117444.0          182948.0           92463.0            49374.0
# 18         114611.0          202407.0           94765.0            59439.0
# 19         121066.0          202463.0          102337.0            61639.0
# 20         110340.0          209063.0           87352.0            58644.0
# 21         109669.0          191723.0           96564.0            63955.0
# 22         115275.0          216837.0          105114.0            63494.0
# 23         102287.0          189764.0           98249.0            60977.0
# 24         102948.0          198542.0           95431.0            59262.0
# 25          99293.0          199243.0           93443.0            61496.0
# 26          96995.0          188707.0           86745.0            58325.0
# 27          99563.0          195919.0           93111.0            51081.0
# 28          94654.0          181064.0           88376.0            51557.0
# 29          90276.0          187056.0          100644.0            56229.0
# 30          85904.0          189357.0           92774.0            59149.0
# 31          91997.0          202364.0          110859.0            62700.0
# 32          93132.0          194980.0          107865.0            63234.0
# 33          92198.0          178627.0          106998.0            60526.0
# 34          90179.0          196499.0          102152.0            57019.0
# 35          90181.0          206661.0           99943.0            62524.0
# 36          94528.0          209713.0          100013.0            59568.0
# 37          85130.0          183298.0           86217.0            43326.0
#
#     trips_100_250_2020  trips_250_500_2020  trips_500_2020
# 0              24017.0              6539.0          1182.0
# 1              26195.0              5899.0          1342.0
# 2              27763.0              6671.0          1463.0
# 3              24503.0              6476.0          2472.0
# 4              25181.0              7385.0          2734.0
# 5              29365.0              7909.0          3573.0
# 6              32616.0              8713.0          3564.0
# 7              31996.0              7456.0          1911.0
# 8              30773.0              9001.0          2005.0
# 9              28946.0              8446.0          3245.0
# 10             30030.0              8532.0          1913.0
# 11             29409.0              8337.0          2073.0
# 12             30063.0              7587.0          1434.0
# 13             24444.0              6899.0          1049.0
# 14             24397.0              5982.0          1732.0
# 15             21099.0              5653.0           970.0
# 16             26047.0              6119.0          1004.0
# 17             27920.0              6134.0           972.0
# 18             43950.0             11419.0          1902.0
# 19             38963.0              8659.0          1544.0
# 20             38297.0             12368.0          2066.0
# 21             37640.0             12193.0          2455.0
# 22             42504.0             10593.0          2048.0
# 23             42723.0             12400.0          2785.0
# 24             36525.0             10784.0          3138.0
# 25             35199.0              9998.0          3418.0
# 26             30956.0              8650.0          3502.0
# 27             28507.0              8130.0          2832.0
# 28             32850.0              8263.0          3007.0
# 29             32550.0              8910.0          3370.0
# 30             37603.0             11175.0          3001.0
# 31             36316.0             11166.0          5128.0
# 32             37912.0             12006.0          6548.0
# 33             33992.0             10588.0          4501.0
# 34             36800.0             10368.0          3628.0
# 35             37418.0              9374.0          3807.0
# 36             35265.0             10319.0          3941.0
# 37             29366.0              8556.0          1824.0
#
# [38 rows x 23 columns]

# %%
# line graph - did not use for slides
ax, fig1 = plt.subplots()
fig1.plot(dfslcpivot['weeknumber'], dfslcpivot['trips_2019'])
fig1.plot(dfslcpivot['weeknumber'], dfslcpivot['trips_2020'])
fig1.ticklabel_format(style='plain')

# %%
# Bar chart with multiple x's  - weekly trips 2019 vs 2020
plt.rcParams["figure.figsize"]=20,10
n = 38
weektrips19 = dfslcpivot['trips_2019'].to_list()
weektrips20 = dfslcpivot['trips_2020'].to_list()
weeknumbers = dfslcpivot['weeknumber'].to_list()

ind = np.arange(n) 
width = 0.3       
plt.bar(ind, weektrips19, width, label='Weekly Trips, 2019', color='#ffa600')
plt.bar(ind + width, weektrips20, width, label='Weekly Trips, 2020', color='#004d70')


#plt.rcParams["figure.figsize"]=20,10
plt.ticklabel_format(style='plain')
plt.ylabel('Trips', weight="bold", size=12)
plt.xlabel( 'Week Number', weight="bold", size=12)
plt.title('Weekly Trips: 2019 vs. 2020, Box Elder County', weight="bold", size=16)
ax = plt.gca()
ax.get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))

i = 0
for p in ax.patches:
    percentageChangeText = str(int(((weektrips20[i] - weektrips19[i])/weektrips19[i]) *100)).replace("-","- ") + '%'
    width, height = p.get_width(), p.get_height()
    x=p.get_x() + width/2
    y=p.get_y()+2180000
    ax.annotate(percentageChangeText,(x,y), rotation = 45, weight="bold", size=12)
    i = i + 1
    if (i == n):
        break
    
plt.xticks(ind + width / 2, weeknumbers, fontsize=12)
plt.yticks(fontsize=12)
plt.legend(loc='lower right', fontsize = 20, framealpha=1)
plt.show()

# %%
# sum trips by distance values by month
slctripsbymonth_sum = dfslc.groupby(['month', 'year'], as_index=False)[['trips_1', 'trips_1_3', 'trips_3_5', 'trips_5_10',
       'trips_10_25', 'trips_25_50', 'trips_50_100', 'trips_100_250', 'trips_250_500', 'trips_500']].sum()
#slctripsbymonth_sum = slctripsbymonth_sum[(slctripsbyweek_sum['weeknumber']<40) & (slctripsbyweek_sum['weeknumber']>1)]
slctripsbymonth_sum["trips_100_500"] = slctripsbymonth_sum['trips_100_250']+slctripsbymonth_sum['trips_250_500']+slctripsbymonth_sum['trips_500']
slctripsbymonth_sum = slctripsbymonth_sum.drop(['trips_100_250', 'trips_250_500', 'trips_500'], axis=1)
slctripsbymonth_sum
# Out:
#     month  year    trips_1  trips_1_3  trips_3_5  trips_5_10  trips_10_25  \
# 0       1  2019  1688172.0  1676044.0   580272.0    563223.0    1141647.0
# 1       1  2020  1652993.0  1535277.0   597633.0    538483.0    1080044.0
# 2       2  2019  1516314.0  1533108.0   533667.0    506846.0     959868.0
# 3       2  2020  1622965.0  1539991.0   567219.0    536399.0    1050847.0
# 4       3  2019  1794333.0  1995247.0   679836.0    626704.0    1274207.0
# 5       3  2020  1641774.0  1320451.0   515385.0    449486.0     905656.0
# 6       4  2019  1769804.0  2091715.0   778304.0    695165.0    1412968.0
# 7       4  2020  1488946.0  1177071.0   464636.0    396257.0     799250.0
# 8       5  2019  1866018.0  2354107.0   854604.0    757414.0    1492699.0
# 9       5  2020  1590391.0  1329439.0   528034.0    511453.0     875880.0
# 10      6  2019  1935468.0  2393764.0   862781.0    715082.0    1527930.0
# 11      6  2020  1488740.0  1133759.0   468550.0    459767.0     853145.0
# 12      7  2019  2115534.0  2687845.0  1037835.0    846146.0    1785817.0
# 13      7  2020  1212955.0   997480.0   439189.0    427796.0     848706.0
# 14      8  2019  2124850.0  2672900.0   932718.0    886468.0    1760551.0
# 15      8  2020  1131809.0  1026499.0   400823.0    397081.0     840507.0
# 16      9  2019  1826568.0  2289439.0   858482.0    933546.0    1718426.0
# 17      9  2020  1008274.0   965357.0   358445.0    349565.0     767996.0
# 18     10  2019  2127189.0  2360650.0   767838.0    678480.0    1748751.0
# 19     11  2019  2213629.0  2193494.0   791795.0    727651.0    1692654.0
# 20     12  2019  2186933.0  2189055.0   812469.0    792955.0    1746093.0
#
#     trips_25_50  trips_50_100  trips_100_500
# 0      549043.0      261758.0       156315.0
# 1      483908.0      227363.0       147918.0
# 2      487785.0      222745.0       145741.0
# 3      524102.0      248362.0       165698.0
# 4      564033.0      246916.0       205414.0
# 5      412196.0      240405.0       180911.0
# 6      563135.0      241239.0       243609.0
# 7      331712.0      174004.0       138925.0
# 8      576071.0      229037.0       164048.0
# 9      408997.0      245665.0       207504.0
# 10     598901.0      219883.0       161144.0
# 11     421450.0      266106.0       229612.0
# 12     659340.0      219468.0       121044.0
# 13     408449.0      243106.0       193220.0
# 14     779289.0      268940.0       125091.0
# 15     460996.0      270212.0       231521.0
# 16     722659.0      219655.0       128142.0
# 17     373603.0      214998.0       182179.0
# 18     589131.0      188610.0       147668.0
# 19     497612.0      172085.0       157113.0
# 20     528153.0      192343.0       167084.0

# %%
# test .loc function, drop first two columns
slctripsbymonth_sum.loc[16, :].values.tolist()[2:]
# Out:
# [1826568.0,
#  2289439.0,
#  858482.0,
#  933546.0,
#  1718426.0,
#  722659.0,
#  219655.0,
#  128142.0]

# %%
# bar chart - plot trips by distance for the month of septmeber for 2019 and 2020
plt.rcParams["figure.figsize"]=20,10
n = 8
monthtrips19 = slctripsbymonth_sum.loc[16, :].values.tolist()[2:]
monthtrips20 = slctripsbymonth_sum.loc[17, :].values.tolist()[2:]
triplengthlabels = ('< 1 Mile', '1-3 Miles', '3-5 Miles', '5-10 Miles',
       '10-25 Miles', '25-50 Miles', '50-100 Miles', '> 100 Miles')

ind = np.arange(n) 
width = 0.30       
plt.bar(ind, monthtrips19, width, label='September 2019', color='#ffa600')
plt.bar(ind + width, monthtrips20, width, label='September 2020', color='#004d70')

plt.rcParams["figure.figsize"]=20,10
plt.ticklabel_format(style='plain')
plt.ylabel('Trips', weight="bold", size=12)
plt.xlabel('Trip Length', weight="bold", size=12)
plt.title('Trips Originating in Box Elder County by Length', weight="bold", size=16)
ax = plt.gca()
ax.get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))

i = 0
for p in ax.patches:
    percentageChangeText = str(int(((monthtrips20[i] - monthtrips19[i])/monthtrips19[i]) *100)).replace("-","- ") + '%'
    width, height = p.get_width(), p.get_height()
    x=p.get_x() + width/2
    y=p.get_y()+1800000
    ax.annotate(percentageChangeText,(x,y), rotation = 45, weight="bold", size=12)
    i = i + 1
    if (i == n):
        break
        
plt.xticks(ind + width / 2, triplengthlabels, fontsize='12')
plt.yticks(fontsize=12)
plt.legend(loc='upper right', fontsize=20, framealpha=1)
plt.show()

# %%
# Do above as percentage of total trips for month of september
slctripsbymonth_sum2 = dfslc.groupby(['month', 'year'], as_index=False)[['trips','trips_1', 'trips_1_3', 'trips_3_5', 'trips_5_10',
       'trips_10_25', 'trips_25_50', 'trips_50_100', 'trips_100_250', 'trips_250_500', 'trips_500']].sum()
slctripsbymonth_sum2["trips_100_500"] = slctripsbymonth_sum2['trips_100_250']+slctripsbymonth_sum2['trips_250_500']+slctripsbymonth_sum2['trips_500']
slctripsbymonth_sum2 = slctripsbymonth_sum2.drop(['trips_100_250', 'trips_250_500', 'trips_500'], axis=1)

#add percent of total colums and calc
slctripsbymonth_sum2['pcnttrips_1'] = ((slctripsbymonth_sum2['trips_1']/slctripsbymonth_sum2['trips'])*100)
slctripsbymonth_sum2['pcnttrips_1_3'] = ((slctripsbymonth_sum2['trips_1_3']/slctripsbymonth_sum2['trips'])*100)
slctripsbymonth_sum2['pcnttrips_3_5'] = ((slctripsbymonth_sum2['trips_3_5']/slctripsbymonth_sum2['trips'])*100)
slctripsbymonth_sum2['pcnttrips_5_10'] = ((slctripsbymonth_sum2['trips_5_10']/slctripsbymonth_sum2['trips'])*100)
slctripsbymonth_sum2['pcnttrips_10_25'] = ((slctripsbymonth_sum2['trips_10_25']/slctripsbymonth_sum2['trips'])*100)
slctripsbymonth_sum2['pcnttrips_25_50'] = ((slctripsbymonth_sum2['trips_25_50']/slctripsbymonth_sum2['trips'])*100)
slctripsbymonth_sum2['pcnttrips_50_100'] = ((slctripsbymonth_sum2['trips_50_100']/slctripsbymonth_sum2['trips'])*100)
slctripsbymonth_sum2['pcnttrips_100_500'] = ((slctripsbymonth_sum2['trips_100_500']/slctripsbymonth_sum2['trips'])*100)
slctripsbymonth_sum2
# Out:
#     month  year      trips    trips_1  trips_1_3  trips_3_5  trips_5_10  \
# 0       1  2019  6616474.0  1688172.0  1676044.0   580272.0    563223.0
# 1       1  2020  6263619.0  1652993.0  1535277.0   597633.0    538483.0
# 2       2  2019  5906074.0  1516314.0  1533108.0   533667.0    506846.0
# 3       2  2020  6255583.0  1622965.0  1539991.0   567219.0    536399.0
# 4       3  2019  7386690.0  1794333.0  1995247.0   679836.0    626704.0
# 5       3  2020  5666264.0  1641774.0  1320451.0   515385.0    449486.0
# 6       4  2019  7795939.0  1769804.0  2091715.0   778304.0    695165.0
# 7       4  2020  4970801.0  1488946.0  1177071.0   464636.0    396257.0
# 8       5  2019  8293998.0  1866018.0  2354107.0   854604.0    757414.0
# 9       5  2020  5697363.0  1590391.0  1329439.0   528034.0    511453.0
# 10      6  2019  8414953.0  1935468.0  2393764.0   862781.0    715082.0
# 11      6  2020  5321129.0  1488740.0  1133759.0   468550.0    459767.0
# 12      7  2019  9473029.0  2115534.0  2687845.0  1037835.0    846146.0
# 13      7  2020  4770901.0  1212955.0   997480.0   439189.0    427796.0
# 14      8  2019  9550807.0  2124850.0  2672900.0   932718.0    886468.0
# 15      8  2020  4759448.0  1131809.0  1026499.0   400823.0    397081.0
# 16      9  2019  8696917.0  1826568.0  2289439.0   858482.0    933546.0
# 17      9  2020  4220417.0  1008274.0   965357.0   358445.0    349565.0
# 18     10  2019  8608317.0  2127189.0  2360650.0   767838.0    678480.0
# 19     11  2019  8446033.0  2213629.0  2193494.0   791795.0    727651.0
# 20     12  2019  8615085.0  2186933.0  2189055.0   812469.0    792955.0
#
#     trips_10_25  trips_25_50  trips_50_100  trips_100_500  pcnttrips_1  \
# 0     1141647.0     549043.0      261758.0       156315.0    25.514677
# 1     1080044.0     483908.0      227363.0       147918.0    26.390382
# 2      959868.0     487785.0      222745.0       145741.0    25.673806
# 3     1050847.0     524102.0      248362.0       165698.0    25.944265
# 4     1274207.0     564033.0      246916.0       205414.0    24.291435
# 5      905656.0     412196.0      240405.0       180911.0    28.974541
# 6     1412968.0     563135.0      241239.0       243609.0    22.701614
# 7      799250.0     331712.0      174004.0       138925.0    29.953844
# 8     1492699.0     576071.0      229037.0       164048.0    22.498414
# 9      875880.0     408997.0      245665.0       207504.0    27.914511
# 10    1527930.0     598901.0      219883.0       161144.0    23.000342
# 11     853145.0     421450.0      266106.0       229612.0    27.977897
# 12    1785817.0     659340.0      219468.0       121044.0    22.332181
# 13     848706.0     408449.0      243106.0       193220.0    25.424024
# 14    1760551.0     779289.0      268940.0       125091.0    22.247858
# 15     840507.0     460996.0      270212.0       231521.0    23.780258
# 16    1718426.0     722659.0      219655.0       128142.0    21.002477
# 17     767996.0     373603.0      214998.0       182179.0    23.890388
# 18    1748751.0     589131.0      188610.0       147668.0    24.710858
# 19    1692654.0     497612.0      172085.0       157113.0    26.209097
# 20    1746093.0     528153.0      192343.0       167084.0    25.384927
#
#     pcnttrips_1_3  pcnttrips_3_5  pcnttrips_5_10  pcnttrips_10_25  \
# 0       25.331377       8.770109        8.512434        17.254613
# 1       24.511022       9.541337        8.596995        17.243131
# 2       25.958158       9.035901        8.581775        16.252218
# 3       24.617865       9.067404        8.574724        16.798546
# 4       27.011381       9.203527        8.484233        17.250040
# 5       23.303732       9.095676        7.932670        15.983300
# 6       26.830828       9.983454        8.917014        18.124411
# 7       23.679705       9.347306        7.971693        16.078898
# 8       28.383260      10.303885        9.132074        17.997340
# 9       23.334286       9.268042        8.977013        15.373428
# 10      28.446552      10.252951        8.497754        18.157321
# 11      21.306738       8.805462        8.640403        16.033158
# 12      28.373660      10.955683        8.932159        18.851594
# 13      20.907581       9.205578        8.966776        17.789218
# 14      27.986117       9.765855        9.281603        18.433531
# 15      21.567606       8.421628        8.343005        17.659758
# 16      26.324719       9.871107       10.734218        19.759025
# 17      22.873498       8.493118        8.282712        18.197159
# 18      27.422898       8.919723        7.881680        20.314668
# 19      25.970701       9.374756        8.615299        20.040817
# 20      25.409558       9.430772        9.204262        20.267856
#
#     pcnttrips_25_50  pcnttrips_50_100  pcnttrips_100_500
# 0          8.298121          3.956155           2.362512
# 1          7.725693          3.629898           2.361542
# 2          8.259040          3.771456           2.467646
# 3          8.378148          3.970245           2.648802
# 4          7.635802          3.342715           2.780867
# 5          7.274564          4.242743           3.192774
# 6          7.223440          3.094419           3.124819
# 7          6.673210          3.500522           2.794821
# 8          6.945637          2.761479           1.977912
# 9          7.178707          4.311907           3.642106
# 10         7.117105          2.613003           1.914972
# 11         7.920312          5.000931           4.315099
# 12         6.960181          2.316767           1.277775
# 13         8.561255          5.095599           4.049969
# 14         8.159405          2.815888           1.309743
# 15         9.685913          5.677381           4.864451
# 16         8.309370          2.525665           1.473419
# 17         8.852277          5.094236           4.316611
# 18         6.843742          2.191021           1.715411
# 19         5.891665          2.037465           1.860199
# 20         6.130561          2.232630           1.939435

# %%
# plot 
plt.rcParams["figure.figsize"]=20,10
n = 8
monthtrips19 = slctripsbymonth_sum2.loc[16, :].values.tolist()[11:]
monthtrips20 = slctripsbymonth_sum2.loc[17, :].values.tolist()[11:]
triplengthlabels = ('< 1 Mile', '1-3 Miles', '3-5 Miles', '5-10 Miles',
       '10-25 Miles', '25-50 Miles', '50-100 Miles', '> 100 Miles')

ind = np.arange(n) 
width = 0.30       
plt.bar(ind, monthtrips19, width, label='September 2019', color='#ffa600')
plt.bar(ind + width, monthtrips20, width, label='September 2020', color='#004d70')

plt.rcParams["figure.figsize"]=20,10
plt.ticklabel_format(style='plain')
plt.ylabel('Percent of Total Trips (September)', weight="bold", size=12)
plt.xlabel('Trip Length', weight="bold", size=12)
plt.title('Trips Originating in Box Elder County by Length', weight="bold", size=16)
ax = plt.gca()
ax.get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))

# i = 0
# for p in ax.patches:
#     percentageChangeText = str(int(((monthtrips20[i] - monthtrips19[i])/monthtrips19[i]) *100)).replace("-","- ") + '%'
#     width, height = p.get_width(), p.get_height()
#     x=p.get_x() + width/2
#     y=p.get_y()+35000000
#     ax.annotate(percentageChangeText,(x,y), rotation = 45, weight="bold", size=12)
#     i = i + 1
#     if (i == n):
#         break
        
plt.xticks(ind + width / 2, triplengthlabels, fontsize='12')
plt.yticks(fontsize=12)
plt.legend(loc='upper right', fontsize=20, framealpha=1)
plt.show()

# %%
# pop staying at home
# sum poptotal and popstayathome values by week
# filter down to weeks 2 - 39
# add new column and calculate percent
slcpcnthome_sum = dfslc.groupby(['weeknumber', 'year'], as_index=False)[['poptotal', 'pop_stay_at_home']].sum()
slcpcnthome_sum = slcpcnthome_sum[(slcpcnthome_sum['weeknumber']<40)& (slcpcnthome_sum['weeknumber']>1)]
slcpcnthome_sum["pcntstayhome"] = (slcpcnthome_sum["pop_stay_at_home"]/slcpcnthome_sum["poptotal"])*100
slcpcnthome_sum
# Out:
#     weeknumber  year  poptotal  pop_stay_at_home  pcntstayhome
# 2            2  2019  383474.0           77215.0     20.135655
# 3            2  2020  384650.0           83214.0     21.633693
# 4            3  2019  383474.0           75009.0     19.560387
# 5            3  2020  384650.0           81968.0     21.309762
# 6            4  2019  383474.0           73398.0     19.140281
# ..         ...   ...       ...               ...           ...
# 73          37  2020  384650.0          101865.0     26.482517
# 74          38  2019  383474.0           73104.0     19.063613
# 75          38  2020  384650.0           97583.0     25.369297
# 76          39  2019  383474.0           71952.0     18.763202
# 77          39  2020  329700.0           80856.0     24.524113
#
# [76 rows x 5 columns]

# %%
# filter 2019 and 2020 observations and save to variables - then merge into a table with weeknumber
# we did this so we could graph multiple x values - compare 2019 and 2020 population
weeknumbers = slcpcnthome_sum[['weeknumber']].drop_duplicates()
dfpop2019 = slcpcnthome_sum[slcpcnthome_sum['year']==2019]
dfpop2019.columns = ['weeknumber', 'year', 'poptotal2019', 'pop_stay_at_home_2019', 'pcntstayhome2019']
dfpop2020 = slcpcnthome_sum[slcpcnthome_sum['year']==2020]
dfpop2020.columns = ['weeknumber', 'year', 'poptotal2020', 'pop_stay_at_home_2020', 'pcntstayhome2020']
dfslcpoppivot = weeknumbers.merge(dfpop2019.drop(['year'], axis = 1), left_on = 'weeknumber', right_on = 'weeknumber', how = 'inner')
dfslcpoppivot = dfslcpoppivot.merge(dfpop2020.drop(['year'], axis = 1), left_on = 'weeknumber', right_on = 'weeknumber', how = 'inner')
dfslcpoppivot
# Out:
#     weeknumber  poptotal2019  pop_stay_at_home_2019  pcntstayhome2019  \
# 0            2      383474.0                77215.0         20.135655
# 1            3      383474.0                75009.0         19.560387
# 2            4      383474.0                73398.0         19.140281
# 3            5      383474.0                73416.0         19.144975
# 4            6      383474.0                75036.0         19.567428
# 5            7      383474.0                73335.0         19.123852
# 6            8      383474.0                74778.0         19.500149
# 7            9      383474.0                75440.0         19.672781
# 8           10      383474.0                76901.0         20.053772
# 9           11      383474.0                74327.0         19.382540
# 10          12      383474.0                77943.0         20.325498
# 11          13      383474.0                75568.0         19.706160
# 12          14      383474.0                78004.0         20.341405
# 13          15      383474.0                78575.0         20.490307
# 14          16      383474.0                77578.0         20.230315
# 15          17      383474.0                71153.0         18.554843
# 16          18      383474.0                74169.0         19.341337
# 17          19      383474.0                75310.0         19.638880
# 18          20      383474.0                74453.0         19.415397
# 19          21      383474.0                75943.0         19.803950
# 20          22      383474.0                75823.0         19.772657
# 21          23      383474.0                76526.0         19.955981
# 22          24      383474.0                73464.0         19.157492
# 23          25      383474.0                73641.0         19.203649
# 24          26      383474.0                74529.0         19.435216
# 25          27      383474.0                71403.0         18.620037
# 26          28      383474.0                71103.0         18.541805
# 27          29      383474.0                72676.0         18.952002
# 28          30      383474.0                76936.0         20.062899
# 29          31      383474.0                76441.0         19.933816
# 30          32      383474.0                74228.0         19.356723
# 31          33      383474.0                70248.0         18.318843
# 32          34      383474.0                68451.0         17.850232
# 33          35      383474.0                71261.0         18.583007
# 34          36      383474.0                74548.0         19.440171
# 35          37      383474.0                70253.0         18.320147
# 36          38      383474.0                73104.0         19.063613
# 37          39      383474.0                71952.0         18.763202
#
#     poptotal2020  pop_stay_at_home_2020  pcntstayhome2020
# 0       384650.0                83214.0         21.633693
# 1       384650.0                81968.0         21.309762
# 2       384650.0                82620.0         21.479267
# 3       384650.0                77843.0         20.237359
# 4       384650.0                80358.0         20.891200
# 5       384650.0                76743.0         19.951384
# 6       384650.0                81617.0         21.218510
# 7       384650.0                77196.0         20.069154
# 8       384650.0                76297.0         19.835435
# 9       384650.0                85176.0         22.143767
# 10      384650.0               105619.0         27.458469
# 11      384650.0               107247.0         27.881711
# 12      384650.0               114070.0         29.655531
# 13      384650.0               112059.0         29.132718
# 14      384650.0               110339.0         28.685558
# 15      384650.0               105197.0         27.348759
# 16      384650.0               102644.0         26.685038
# 17      384650.0               100595.0         26.152346
# 18      384650.0                85619.0         22.258937
# 19      384650.0                79036.0         20.547511
# 20      384650.0                87192.0         22.667880
# 21      384650.0                86479.0         22.482517
# 22      384650.0                86137.0         22.393605
# 23      384650.0                87838.0         22.835825
# 24      384650.0                88786.0         23.082283
# 25      384650.0                97306.0         25.297283
# 26      384650.0                93697.0         24.359028
# 27      384650.0                97535.0         25.356818
# 28      384650.0                99453.0         25.855453
# 29      384650.0                99908.0         25.973742
# 30      384650.0                94606.0         24.595346
# 31      384650.0                90325.0         23.482387
# 32      384650.0                93006.0         24.179384
# 33      384650.0                97671.0         25.392175
# 34      384650.0                97641.0         25.384375
# 35      384650.0               101865.0         26.482517
# 36      384650.0                97583.0         25.369297
# 37      329700.0                80856.0         24.524113

# %%
# bar chart - multiple x's 
plt.rcParams["figure.figsize"]=20,10
n = 38
pcntstayhome2019 = dfslcpoppivot['pcntstayhome2019'].to_list()
pcntstayhome2020 = dfslcpoppivot['pcntstayhome2020'].to_list()
weeknumbers = dfslcpoppivot['weeknumber'].to_list()

ind = np.arange(n) 
width = 0.3       
plt.bar(ind, pcntstayhome2019, width, label='% Staying Home, 2019', color='#ffa600')
plt.bar(ind + width, pcntstayhome2020, width, label='% Staying Home, 2020', color='#004d70')

#plt.rcParams["figure.figsize"]=20,10
plt.ticklabel_format(style='plain')
plt.ylabel('Percent of Total Population', weight="bold", size=12)
plt.xlabel('Week Number', weight="bold", size=12)
plt.title('Percent of Population Staying Home: 2019 vs. 2020, Box Elder County', weight="bold", size=16)
ax = plt.gca()
ax.get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))

i = 0
for p in ax.patches:
    percentageChangeText = str(int(((pcntstayhome2020[i] - pcntstayhome2019[i])/pcntstayhome2019[i])*100)).replace("-","- ") + '%'
    width, height = p.get_width(), p.get_height()
    x=p.get_x() + width/2
    y=p.get_y()+29.5
    ax.annotate(percentageChangeText,(x,y), rotation = 45, weight="bold", size=12)
    i = i + 1
    if (i == n):
        break
    
plt.xticks(ind + width / 2, weeknumbers, size=12)
plt.yticks(size=12)
plt.legend(loc='lower right', fontsize=20, framealpha=1)
plt.show()
#plt.savefig(".\\saltlake_pcntpopstayinghome.png")
